# %% [markdown]
# ## Урок 3. Описательная статистика. Качественные и количественные характеристики популяции. Графическое представление данных

# %%
import numpy as np

# %% [markdown]
# #### Задание 1
# Даны значения зарплат из выборки выпускников: 100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150.
# Посчитать (желательно без использования статистических методов наподобие std, var, mean) среднее арифметическое,
# среднее квадратичное отклонение, смещенную и несмещенную оценки дисперсий для данной выборки.

# %%
zp = np.array([100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150])

# %%
mean = zp.sum() / zp.shape[0]
mean
# Out:
# 65.3

# %%
std = np.sqrt(np.sum((zp - mean) ** 2) / zp.shape[0])
std
# Out:
# 30.823854398825596

# %%
var = std ** 2
var
# Out:
# 950.11

# %%
var_1 = (np.sum((zp - mean) ** 2)) / (zp.shape[0] - 1)
var_1
# Out:
# 1000.1157894736842

# %% [markdown]
# #### Задание 2
# В первом ящике находится 8 мячей, из которых 5 - белые. Во втором ящике - 12 мячей, из которых 5 белых. Из первого ящика
# вытаскивают случайным образом два мяча, из второго - 4. Какова вероятность того, что 3 мяча белые?

# %%
def combinations(n, k):
    return int(np.math.factorial(n) / (np.math.factorial(k) * np.math.factorial(n - k)))

# %%
# Из первого 1 белый, из второго 2 белых
P1 = (combinations(5, 1) * combinations(3, 1) / combinations(8, 2)) * \
            (combinations(5, 2) * combinations(7, 2) / combinations(12, 4))

# Из первого 2 белых, из второго 1 белый
P2 = combinations(5, 2) / combinations(8, 2) * (combinations(5, 1) * combinations(7, 3) / combinations(12, 4))

# Из первого 0 белых, из второго - 3 
P3 = combinations(3, 2) / combinations(8, 2) * (combinations(5, 3) * combinations(7, 1) / combinations(12, 4))

# Вероятность события
P = P1 + P2 + P3
P
# Out:
# 0.3686868686868687

# %% [markdown]
# #### Задание 3
# На соревновании по биатлону один из трех спортсменов стреляет и попадает в мишень. Вероятность попадания для первого спортсмена
# равна 0.9, для второго — 0.8, для третьего — 0.6. Найти вероятность того, что выстрел произведен: a). первым спортсменом
# б). вторым спортсменом в). третьим спортсменом.

# %%
# B1 - стрелял 1 спортсмен, В2 - стрелял 2 спортсмен, В3 - стрелял третий спортсмен. A - попадание в мишень.

p_b1 = p_b2 = p_b3 = 1 / 3

p_a_b1 = 0.9
p_a_b2 = 0.8
p_a_b3 = 0.6

p_a = p_b1 * p_a_b1 + p_b2 * p_a_b2 + p_b3 * p_a_b3

p_b1_a = p_a_b1 * p_b1 / p_a
p_b2_a = p_a_b2 * p_b2 / p_a
p_b3_a = p_a_b3 * p_b3 / p_a

print('Вероятность того, что выстрел произведен первым спортсменом: ', p_b1_a)
print('Вероятность того, что выстрел произведен вторым спортсменом: ', p_b2_a)
print('Вероятность того, что выстрел произведен третьим спортсменом: ', p_b3_a)
# Out:
# Вероятность того, что выстрел произведен первым спортсменом:  0.391304347826087
# Вероятность того, что выстрел произведен вторым спортсменом:  0.3478260869565218
# Вероятность того, что выстрел произведен третьим спортсменом:  0.2608695652173913

# %% [markdown]
# #### Задание 4
# В университет на факультеты A и B поступило равное количество студентов, а на факультет C студентов поступило столько же,
# сколько на A и B вместе. Вероятность того, что студент факультета A сдаст первую сессию, равна 0.8. Для студента факультета B
# эта вероятность равна 0.7, а для студента факультета C - 0.9. Студент сдал первую сессию. Какова вероятность, что он учится:
# a). на факультете A б). на факультете B в). на факультете C?

# %%
# В1 - студент учится на факультете А, В2 - студент учится на факультете В, В3 - студент учится на факультете С, 
# А - студент сдал сессию
# x - студентов поступило на факультет А и на факультет В, тогда на факультет С - 2х, всего студентов - 4х

p_b1 = 1 / 4
p_b2 = 1 / 4
p_b3 = 2 / 4

p_a_b1 = 0.8
p_a_b2 = 0.7
p_a_b3 = 0.9

p_a = p_b1 * p_a_b1 + p_b2 * p_a_b2 + p_b3 * p_a_b3

p_b1_a = p_a_b1 * p_b1 / p_a
p_b2_a = p_a_b2 * p_b2 / p_a
p_b3_a = p_a_b3 * p_b3 / p_a

print('Вероятность того, что студент учится на факультете А: ', p_b1_a)
print('Вероятность того, что студент учится на факультете В: ', p_b2_a)
print('Вероятность того, что студент учится на факультете С: ', p_b3_a)
# Out:
# Вероятность того, что студент учится на факультете А:  0.24242424242424246
# Вероятность того, что студент учится на факультете В:  0.21212121212121213
# Вероятность того, что студент учится на факультете С:  0.5454545454545455

# %% [markdown]
# #### Задание 5
# Устройство состоит из трех деталей. Для первой детали вероятность выйти из строя в первый месяц равна 0.1, для второй - 0.2,
# для третьей - 0.25. Какова вероятность того, что в первый месяц выйдут из строя: а). все детали б). только две детали
# в). хотя бы одна деталь г). от одной до двух деталей?

# %%
P1 = 0.1
P2 = 0.2
P3 = 0.25

P_a = P1 * P2 * P3
P_b = P1 * P2 * (1 - P3) + P1 * (1 - P2) * P3 + (1 - P1) * P2 * P3
P_c = 1 - (1 - P1) * (1 - P2) * (1 - P3)
P_d = P1 * (1 - P2) * (1 - P3) + (1 - P1) * P2 * (1 - P3) + (1 - P1) * (1 - P2) * P3 + P_b

print("Вероятность что в первый месяц выйдут из строя все детали: ", P_a)
print("Вероятность что в первый месяц выйдут из строя только 2 детали: ", P_b)
print("Вероятность что в первый месяц выйдет из строя хотя бы одна деталь: ", P_c)
print("Вероятность что в первый месяц выйдут из строя от одной до двух деталей: ", P_d)
# Out:
# Вероятность что в первый месяц выйдут из строя все детали:  0.005000000000000001
# Вероятность что в первый месяц выйдут из строя только 2 детали:  0.08000000000000002
# Вероятность что в первый месяц выйдет из строя хотя бы одна деталь:  0.45999999999999996
# Вероятность что в первый месяц выйдут из строя от одной до двух деталей:  0.455
